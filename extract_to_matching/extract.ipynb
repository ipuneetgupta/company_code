# %%
# !pip install pdfminer
# !pip install PyPDF2
import io
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfpage import PDFPage
import PyPDF2
import os
import math

def get_pdf_text(inputFileName):
    text_list = []
    with open(inputFileName, 'rb') as fh:
        for page in PDFPage.get_pages(fh, caching=True, check_extractable=True):
            resource_manager = PDFResourceManager()
            fake_file_handle = io.StringIO()
            converter = TextConverter(resource_manager, fake_file_handle)
            page_interpreter = PDFPageInterpreter(resource_manager, converter)
            page_interpreter.process_page(page)
            s = fake_file_handle.getvalue()
            s = s.split("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            converter.close()
            fake_file_handle.close()
            try:
                text_list.append(get_name(s[2]))
            except:
                continue
    return text_list

def get_pdf_roll_no(data):
    import re
    roll_no = re.findall(r'\b\d{10}\b', data)
    return roll_no

def get_name(data):
    name = []
    roll_number = []
    temp = []
    text = data.split(' ')
    n = len(text)
    c = 0
    while c<n:
        if text[c] != "":
            try:
                p = text[c].replace('.',"")
                p = p.strip()
                p = int(p)
                if math.floor(math.log10(p)+1) == 10:
                    roll_number.append(p)
            except:
                try:
                    p = text[c+1].replace('.',"")
                    p = int(p)
                    name.append(text[c])
                except:
                    try:
                        p = text[c+2].replace('.',"")
                        p = int(p)
                        name.append(text[c]+" "+text[c+1].strip)
                        c += 1
                    except:
                        name.append(text[c] + " " + text[c+1] + " "+ text[c+2])
                        c += 2
        c+=1
    for x in name:
        if x.find('0') != -1:
            name.remove(x)
        
    return name
    
def get_pdf_data(inputFileName):
    text = get_pdf_text(inputFileName)
    temp = []
    for t in text:
        for x in t:
            temp.append(x.strip())
    return temp

# %%
name1 = get_pdf_data("LIST3_ROLL-LDC_25022020.pdf")
name2 = get_pdf_data("LIST_3_01042021.pdf")

# %%
list(set(roll_no_1).intersection(set(roll_no_2)))
# Out:
# ['DILBAG SINGH',
#  'DEACHEN ANGMO',
#  'GAURAV KUMAR',
#  'PANKAJ KUMAR',
#  'ANMOL DUBEY',
#  'ROHIT KUMAR',
#  'ANUJ SANGRAL',
#  'SABORNI SANFUI',
#  'SUSHANT GUPTA',
#  'ANMOL GUPTA',
#  'RAVINDER SINGH',
#  'RISHABH DHAWAN',
#  'DEVENDER KUMAR',
#  'UPENDRA KUMAR SINGH',
#  'ROHIT KUMAR',
#  'ARJUN SHARMA',
#  'JATIN KUMAR',
#  'VISHAV JARAL',
#  'ARUN KUMAR',
#  'ADARSH KUMAR',
#  'ROHIT SHARMA',
#  'ADITYA RANJAN',
#  'RAJESH KUMAR',
#  'RUCHIKA HAKU',
#  'KRUN BAWA',
#  'PUSHPANI.',
#  'DARVINDER SINGH',
#  'NIKHIL SHARMA',
#  'KULWINDER SINGH',
#  'RAVINDER KUMAR',
#  'AJAY SHARMA',
#  'AKSHIT GUPTA',
#  'MEENAKSHI',
#  'SANDEEP KUMAR',
#  'PAWANDEEP SINGH',
#  'NARINDER SINGH',
#  'KANAV GUPTA',
#  'MANU KANATHIA',
#  'PADMA DORJAY',
#  'RANJAN',
#  'ABISHAKE KUMAR',
#  'SHARANG SHARMA',
#  'DECHEN CHUSKIT',
#  'MAMTA CHOUDHARY',
#  'RAHUL DEV SINGH',
#  'SAKET DUTTA',
#  'RAHUL BHARATI',
#  'BANARSI LAL',
#  'RAHUL SHARMA',
#  'SAHIL',
#  'SANJEEV KUMAR',
#  'RAHUL SHARMA',
#  'VIVEK SHARMA',
#  'SAGAR QANOONGO',
#  'SUSHANT',
#  'YANGCHAN DOLMA',
#  'ABHISHEK KUMAR',
#  'MOHD AMIN BHAT',
#  'RAJINDER SINGH',
#  'TAWQUIR AHMAD GANIE',
#  'RAHUL THAKUR',
#  'MOHAMMAD DANISH BHAT',
#  'DEVA NAND',
#  'MANZOOR AHMAD BHAT',
#  'DIKSHA CHIB',
#  'VIKRAM BADAL',
#  'RISHABH GUPTA',
#  'AJAZ AHMAD DAR',
#  'MUKESH  ATRI',
#  'MOHD YOUSUF MIR',
#  'KAILASH BAVORIA',
#  'JANGBIR SINGH',
#  'ASHWANI KUMAR',
#  'JATINDER THAKUR',
#  'AJAY SHARMA',
#  'DIGVIJAY SINGH',
#  'KULDEEP RAJ',
#  'SUBHASH CHANDER',
#  'AJAY SHARMA',
#  'SURINDER KUMAR',
#  'UDIT  KALSI',
#  'SUNESH KUMAR',
#  'ASHWANI KUMAR',
#  'RAJAT SETHI',
#  'HIMANSHU LEHRA',
#  'NITAN BABORIA',
#  'VISHAL',
#  'AMAN KUMAR',
#  'ASHISH MANOTRA',
#  'AMIT KUMAR',
#  'SAHIL SHARMA',
#  'VIJAY KUMAR',
#  'VISHAL CHOUDHARY',
#  'AVANTIKA BHARDWAJ',
#  'SURINDER SINGH',
#  'RAJESH KUMAR',
#  'SUSHANT ATRI',
#  'AMAN KAPOOR',
#  'RAHUL KUMAR',
#  'SURESH KUMAR',
#  'VIVEK KUMAR SHARMA',
#  'KRISHAN KUMAR SHARMA',
#  'SWETA SHARMA',
#  'HEM LATA',
#  'KARAM SINGH',
#  'AJAY KUMAR RANA',
#  'SUNIL KUMAR',
#  'SUBHASH CHAND',
#  'RANJIT SINGH',
#  'DEEPAK',
#  'RAJEEV KUMAR',
#  'VED RAM',
#  'MANOJ KUMAR',
#  'DHARMENDER KUMAR',
#  'AKSHAY DHIMAN',
#  'DEEKSHA SHARMA',
#  'RAHUL',
#  'VIVEK BHARTI SHARMA',
#  'VIJAY MALIK',
#  'DUSHYANT KUMAR',
#  'PARMOD',
#  'HEMANT VAISH',
#  'SONU',
#  'JAYANT SHARMA',
#  'NAVEEN DHALWAL',
#  'VINEET',
#  'AMIT',
#  'SANJAY THAKUR',
#  'SOMBIR',
#  'DEEPAK SHARMA',
#  'ASHISH GOYAT',
#  'SUDODHAN NEGI',
#  'VIVEK BHARDWAJ',
#  'ARUN KUMAR',
#  'ABHISHEK CHANDEL',
#  'SHUBHDEEP SINGH',
#  'ABHISHEK NEGI',
#  'ARUN SHARMA',
#  'SHIV KUMAR',
#  'RANJIT KUMAR',
#  'SUSHEEL KUMAR',
#  'ASHOK KUMAR',
#  'NAVEEN KUMAR',
#  'RAMAN DHIMAN',
#  'AJAY SHARMA',
#  'RAJEEB KUMAR MEHTA',
#  'RAVI KUMAR',
#  'KASHISH MALHOTRA',
#  'RAJAT KUMAR',
#  'RAJESH KUMAR KATOCH',
#  'SANJAY',
#  'KULBIR SINGH BISHT',
#  'VANDANA CHAUHAN',
#  'GAURAV VERMA',
#  'NARENDER NATH GAUTAM',
#  'BHAJANLAL',
#  'PANKAJ MEHRA',
#  'AKSHAY MOHLA',
#  'ANOOP SINGH',
#  'SUKHWINDER SINGH SODHI',
#  'VIPAN KUMAR',
#  'BHAGU NANDAN',
#  'JITENDER',
#  'SANTOSH KUMAR TRIPATHI',
#  'DHARAM PRAKASH',
#  'RANJAN BHUTUNGRU',
#  'MANISH SHARMA',
#  'SANDEEP SRIVASTAW',
#  'BHASKAR CH MANDAL',
#  'MUKESH RANJAN SHARMA',
#  'RAKESH KUMAR',
#  'MANJEET KUMAR',
#  'BALBIR SINGH',
#  'AMAN CHUGH',
#  'MANOJ KUMAR VERMA',
#  'KULDEEP SINGH',
#  'PRAVEEN KUMAR',
#  'SUBHASH PRASAD',
#  'VARUN',
#  'SURESH KUMAR',
#  'VINEY KUMAR',
#  'RAMANDEEP SINGH',
#  'NARESH KUMAR',
#  'VIKRAM SINGH',
#  'ANIL KUMAR',
#  'GAURANG CHAMOLA',
#  'RAJESH KUMAR',
#  'SUMIT KUMAR',
#  'RAKESH KUMAR',
#  'RAOUSHAN KUMAR VERMA',
#  'SATISH KUMAR',
#  'PALLAVI',
#  'VIKAS SHARMA',
#  'DEEPAK PANWAR',
#  'RAJ KUMAR',
#  'VINAY KUMAR TIWARI',
#  'PARTEEK PIZAR',
#  'SHASHI CHANDAN KUMAR',
#  'SING',
#  'MANOJ KUMAR',
#  'VARINDER KUMAR',
#  'SACHIN DEV',
#  'UMA BHATOA',
#  'AMIT KUMAR',
#  'PRASHANT CHAND',
#  'SKINA RANI',
#  'JAGMAIL SINGH',
#  'NISHANT GILL',
#  'ANKIT KUMAR',
#  'ASHOK KUMAR JHA',
#  'PARDEEP KUMAR',
#  'HIMANSHU ASIJA',
#  'KHANJESH KUMAR',
#  'ASHWAINI KUMAR',
#  'DEEPAK SHARMA',
#  'MANISH GAUTAM',
#  'SUMIT CHAHAL',
#  'KSHITIJ DUREJA',
#  'MANOHAR LAL',
#  'ROBIN SINGH',
#  'ABHIMANYU GAUTAM',
#  'MANOJ KUMAR JHA',
#  'TARO DEVI',
#  'HITAKSHI SETIA',
#  'VIPUL CHAKRADHAR',
#  'BARE LAL GUPTA',
#  'SONI CHOUDHARY',
#  'SHUBHAM SHARMA',
#  'SOURABH KUMAR',
#  'MANJEET KUMAR',
#  'MANPREET SINGH',
#  'CHARU',
#  'RAVJOT SINGH',
#  'RAVINDER SINGH',
#  'BAIDYA NATH CHOUDHARY',
#  'ANNU',
#  'RUPALI',
#  'DEEPIKA RANI',
#  'RICHPAL',
#  'PANKAJ ARORA',
#  'SHAMBHU KUMAR',
#  'SHAMBHU KUMAR SINGH',
#  'RAHUL MAAN',
#  'MAHAKI MEENA',
#  'JAYANT HOODA',
#  'RAM CHANDER',
#  'ANMOL RATTAN',
#  'SHUBHENDER PRAKASH',
#  'ANIL KUMAR',
#  'KAILASH SINGH BORA',
#  'SURENDER SINGH',
#  'PRADEEP LOHAN',
#  'LOVEPREET SINGH',
#  'PRIYANKA',
#  'PARAS BANSAL',
#  'SUMIT SHARMA',
#  'JASPAL SINGH',
#  'RENU',
#  'AWDESH KUMAR ROY',
#  'RAJIV KUMAR',
#  'MAYANK MANI GAUTAM',
#  'BHANU GUPTA',
#  'SUNIL KUMAR LILOO',
#  'MUKESH KUMAR SINGH',
#  'BIST',
#  'SANJEEV KUMAR',
#  'SHASHI SEKHAR KUMAR',
#  'MANISH KUMAR GABA',
#  'PUNIT SHARMA',
#  'ABHISHEK RANA',
#  'RAM KUMAR',
#  'DILSHER SINGH',
#  'VIVEK THAKUR',
#  'YOGESH KUMAR',
#  'JITENDRA SHARMA',
#  'TARUN SHARMA',
#  'SONIA',
#  'RAMANPREET SINGH',
#  'SANTOSH KUMAR VERMA',
#  'DIMPLE SACHDEVA',
#  'AJAY KUMAR',
#  'RINCHEN CHHERING',
#  'AJAY KUMAR',
#  'CHANDANDEEP SINGH',
#  'KULDEEP CHAND',
#  'GOVIND PANWAR',
#  'HEMANT JINDAL',
#  'SHARANJIT SINGH',
#  'MANISH KUMAR',
#  'CHETAN KAUNDAL',
#  'VINAY ARORA',
#  'SANDEEP KUMAR',
#  'ROHIT KUMAR',
#  'MD ANZARUL HAQUE',
#  'SANJEEV',
#  'NIRMAL SINGH',
#  'PALLVI RANI',
#  'SHUBHAM KUMAR PANDEY',
#  'SHWETA',
#  'NARESH KUMAR MALL',
#  'RAJA DINESH SINGH',
#  'SARIKA KANDAL',
#  'ARSHDEEP SINGH',
#  'JASPREET SINGH',
#  'TARUN KUMAR',
#  'VIPUL',
#  'SOFIA GUPTA',
#  'AJAY KUMAR',
#  'SRINIVAS V',
#  'SACHIN SAINI',
#  'AMIT',
#  'ANIL KUMAR GUPTA',
#  'SHEO MOORTI YADAV',
#  'RAJAT SAXENA',
#  'LOVISH',
#  'ANURAG SINGH',
#  'ANAND KUMAR MISHRA',
#  'BHUPINDER SINGH',
#  'SALONI THAKUR',
#  'YUGANSH BATHLA',
#  'JAIDEV DHULL',
#  'SATISH KUMAR SAINI',
#  'JITENDRA SINGH',
#  'MAHENDRA PRATAP SINGH',
#  'DAVINDER KUMAR',
#  'SHYAM JEE VERMA',
#  'VILAS SHARMA',
#  'BALVINDER KUMAR',
#  'ABHISHEK SODHI',
#  'BALJINDER SINGH',
#  'VISHAL GOEL',
#  'SHIVRAJ MEENA',
#  'DESHRAM MEENA',
#  'MAHAK VAID',
#  'SUDHIR KUMAR',
#  'VISHAL SINGLA',
#  'AKSHAY KUMAR',
#  'SHUBHAM SHARMA',
#  'VIVEK KUMAR',
#  'ARVIND KUMAR',
#  'SHASHI KUMAR',
#  'RAJEEV CHAMOLI',
#  'MOTILAL PRASAD',
#  'MOHIT MEHRA',
#  'KAPIL',
#  'AMITA KUNDAL',
#  'ABHINASH SINGH',
#  'IMRAN KHAN',
#  'KUMAR RANJAT',
#  'MOHIT SAGAR',
#  'ANUREET KAUR',
#  'ANKIT SHARMA',
#  'VIJAY KUMAR',
#  'HIMANSHU DHIMAN',
#  'SHUBHAM RANA',
#  'MANDEEP SINGH',
#  'SOURAV KAMBOJ',
#  'PAWAN KATARIA',
#  'RAMESH KUMAR PATEL',
#  'ANIL KUMAR',
#  'ARVIND CHAHAL',
#  'RAKESH KUMAR',
#  'ANKIT GARG',
#  'PANKAJ ATWAL',
#  'SAURABH',
#  'PARVEEN KUMAR',
#  'ASHIS KUMAR NATH',
#  'VASU DEV',
#  'RAMANDEEP SINGH',
#  'NIKHIL ARORA',
#  'RAVI KUMAR',
#  'SHAILENDER KUMAR',
#  'AJEET KUMAR SHARMA',
#  'BHARAT DAHIYA',
#  'SANDEEP CHAND',
#  'ABHISHEK SHARMA',
#  'JATIN SINGH KUSHWAHA',
#  'AMIT SINGH',
#  'NISHANT GUPTA',
#  'DILIP PASWAN',
#  'SANJAY KUMAR MISHRA',
#  'OMKAR SAWROOP',
#  'PUSHPENDRA KUMAR TRIPATHI',
#  'SURINDER SINGH',
#  'JUGENDRA SINGH',
#  'ROHIT',
#  'AARUSH',
#  'PARVEEN',
#  'DINESH',
#  'ARVIND BANSAL',
#  'BHUPINDER SINGH DHINDSA',
#  'VIJAY SINGH',
#  'SATNAM SINGH',
#  'MOHAMMAD ALTAMASH',
#  'KRITIKA LEHRA',
#  'JAGDEEP SINGH',
#  'RUPINDER SINGH',
#  'PARDEEP KUMAR',
#  'NEHA',
#  'KAMAL',
#  'DEEPAK KUMAR',
#  'SARBESHWAR KUMAR',
#  'PRAMOD KUMAR',
#  'BABAN JEE PANDEY',
#  'RITISH SHARMA',
#  'SHOBIT SHARMA',
#  'AKSHAY SAHARAN',
#  'SNEHIL SHARMA',
#  'SAMSON',
#  'RAVI KUMAR SHARMA',
#  'KASHISH SHARMA',
#  'AJMER SINGH',
#  'SUNIL KUMAR',
#  'KARAN DHINGRA',
#  'VISHAVDEEP',
#  'ASHOK KUMAR PAL',
#  'VIVEK KUMAR',
#  'KUNJ BIHARI SINGH',
#  'HARBHAJAN SINGH',
#  'ASHISH',
#  'ABHISHEK KUMAR SINGH',
#  'KUMAR RAKESH',
#  'SUKHJINDER SINGH',
#  'MANJEET SINGH',
#  'KAPIL MAKKAR',
#  'PRIYA KUMARI',
#  'MAYANK ALLAWADI',
#  'VIKRAM',
#  'SURINDER SINGH',
#  'KARTIK DESHWAL',
#  'HARPREET SINGH',
#  'AMRITPAL SINGH',
#  'JATINDER',
#  'HARNOOR KAUR BHATIA',
#  'SHUBHAM TAANK',
#  'PRABHAW KUMAR SINGH',
#  'SANJAY K S',
#  'SATNAM SINGH',
#  'MAQSOOD NAJAF',
#  'TUSHANK KATARIA',
#  'ASHISH',
#  'BALWINDER SINGH',
#  'DINESH KUMAR KALER',
#  'NITIN KUMAR',
#  'AMIT KUMAR',
#  'RAHUL KUMAR',
#  'JAGDEEP SINGH',
#  'AJAY SINGH',
#  'SANJAY KUMAR PANDEY',
#  'MAHADEEP SINGH',
#  'PRAPHOOL CHANDRA SARASWAT',
#  'PUNEET KUMAR',
#  'GAUTAM UPPAL',
#  'DEEPAK',
#  'ABHISHEK MAHLA',
#  'VIVEK SINGH',
#  'AKSHAY KUMAR',
#  'DEVINDER SINGH',
#  'AMANDEEP SINGH',
#  'DINESH BHUTT',
#  'TARANJOT SINGH',
#  'KULDEEP SINGH',
#  'RAMESH KUMAR MEENA',
#  'VEERPAL KAUR',
#  'JATIN HANS',
#  'SANTOSH KUMAR',
#  'RANJIT SINGH',
#  'SONU BALA',
#  'MOHIT GUPTA',
#  'SUNITA',
#  'RAKESH KUMAR SINGH',
#  'SONU',
#  'PRABHJIT KAUR',
#  'SURBHI GARG',
#  'RAJAT KUMAR',
#  'VIPUL MITTAL',
#  'RAVI PRATAP SINGH',
#  'BALJEET',
#  'HIMANSHU SANGWAN',
#  'AMBIKA',
#  'HARISH RAJU',
#  'JYOTI',
#  'SOHIT MEHTA',
#  'JASKARANVIR SINGH',
#  'MOHIT SETHI',
#  'SHRISTEE',
#  'VIKAS',
#  'USHA GOUR',
#  'RISHI KUMAR DUBEY',
#  'ATINDERPAL SINGH',
#  'DALWINDER KUMAR',
#  'SAHIL',
#  'MANOJ KUMAR SINGH',
#  'TANUJ',
#  'TEJINDER SINGH',
#  'NIDHI',
#  'VIJAY KUMAR',
#  'TANYA SINGLA',
#  'RANJIT KUMAR',
#  'RAHUL CHAUDHARY',
#  'DEEPINDER SHARMA',
#  'HONEY KUMAR',
#  'SANJU',
#  'MUKESH KUMAR',
#  'SUMAN RANI',
#  'VIJAYPAL SINGH',
#  'SUSHMA',
#  'MANPREET MALIK',
#  'AMRIT KAUR',
#  'JYOTI',
#  'SHELLY',
#  'ROHIT BAINS',
#  'DEEPAK',
#  'AMIT KUMAR',
#  'NISHA DEVI',
#  'SHIKHA',
#  'NAVDEEP',
#  'AMITA BHALLA',
#  'SUNNY CHAUHAN',
#  'DHARMINDER SINGH',
#  'VINOD DHIMAN',
#  'ROBIN AGGARWAL',
#  'KOMAL SHARMA',
#  'KAMAL PREET SINGH',
#  'TANYA',
#  'RUPALI',
#  'ANKIT',
#  'RUBINDER SINGH',
#  'SAGAR',
#  'CHANIKA BEDI',
#  'JYOTI',
#  'ABHISHEK KHURANA',
#  'SAHIL KUMAR',
#  'HARPREET KAUR',
#  'RAHUL',
#  'RISHAV',
#  'SUNIDHI GARG',
#  'SANDEEP SINGH',
#  'SHALU MANN',
#  'PUNEET KUMAR',
#  'SAMRIDHI',
#  'JASPAL SINGH',
#  'DEEPIKA',
#  'SHAMSHER SINGH',
#  'PRIYANKA',
#  'ANKUR SINGH CHAUHAN',
#  'RANJEETA',
#  'NITIN KUMAR RANA',
#  'DEEPAK KUMAR',
#  'RAM PRAVESH SHUKLA',
#  'HARDEEP KAUR',
#  'RAMANJEET SINGH',
#  'RUPINDER KAUR',
#  'KOMAL',
#  'RITU RANI',
#  'KRITAGYA MAHAJAN',
#  'DEEPIKA',
#  'SURAJ',
#  'SHERRY',
#  'PARVESH LATHER',
#  'JAGDEEP KAUR',
#  'TARUN',
#  'JATINDER MITTAL',
#  'ROHAN KUMAR',
#  'BALJOT SINGH',
#  'SUDEEP SINGH',
#  'KHEM BHADUR THAPA',
#  'OM NATH',
#  'SUJATA',
#  'NITESH RAHEJA',
#  'GURJOT KAUR',
#  'NAVEEN',
#  'RITU RANI',
#  'SAURAV DADWAL',
#  'AMRINDER SINGH',
#  'JAGDEEP SINGH',
#  'SUMIT KUMAR',
#  'PREETI SACHDEVA',
#  'PRIYANKA',
#  'HARJINDER SINGH',
#  'USHA RANI',
#  'ARUN KUMAR PANKAJ',
#  'RANJEET PATHANIA',
#  'CHANPREET SINGH',
#  'AMIT',
#  'KRISHAN KUMAR',
#  'SWETA SHOKEEN',
#  'SANJEEV KUMAR PRADHAN',
#  'SHIVANI GOYAL',
#  'SUMIT KUMAR',
#  'PRIYA GUPTA',
#  'RANJEET KUMAR',
#  'HUMESH GOYAL',
#  'MOHIT BASSI',
#  'BALWANT SINGH',
#  'ANMOL SINGH',
#  'LAKSHIKA BHARTI',
#  'TEJINDERPAL SINGH',
#  'DIVYA RANA',
#  'SHUBHAM KRIR',
#  'HEENA',
#  'RANJEET KUMAR SINGH',
#  'BHOLA PRASAD SAH',
#  'RAMANDEEP SINGH',
#  'AMAN SINGH BIST',
#  'YOGESH SHARMA',
#  'RAM PAL SHARMA',
#  'SOHAN LAL',
#  'KAMLESH PANDEY',
#  'ANKITA',
#  'RAKESH KUMAR',
#  'ABHISHEK KADIAN',
#  'SHIKHA GUPTA',
#  'MITHILESH KUMAR KUSHWAHA',
#  'SUKHBEER',
#  'DEEP CHAND',
#  'SHUBHAM SAINI',
#  'GAURAV BHANWAR',
#  'ARUN KUMAR DAS',
#  'LAKSHAY KUMAR LAKRA',
#  'VIKRAM SINGH CHAUHAN',
#  'VIKASH',
#  'AMIT KUMAR JHA',
#  'YOGESH',
#  'MUKESH KUMAR',
#  'ARUSH SHARMA',
#  'BIPIN JAISWAL',
#  'MOHINI WALIA',
#  'MUKESH KUMAR SINGH',
#  'ANJU',
#  'PANKAJ SHARMA',
#  'MANPREET SINGH',
#  'NEELAM',
#  'ANKITA',
#  'JASVIR SINGH',
#  'TARUN KHAMPA',
#  'TEJVIR SHARMA',
#  'VINIT NAIN',
#  'DEVVRAT',
#  'RAJIV',
#  'SUPRIYO DEY',
#  'SACHIN',
#  'AMIT KUMAR',
#  'SACHIN ANGARIA',
#  'SURENDER KUMAR',
#  'ALOK SHARMA',
#  'MOHIT KALYAN',
#  'DHARMBIR',
#  'SOURAV',
#  'SUDHIR',
#  'BIJENDER',
#  'KAMLESH THAKUR',
#  'SUBASH CHAND',
#  'KARAN PUNDIR',
#  'ABHISHEK SINGLA',
#  'SONAM VERMA',
#  'SUBHASHIS PUSHILAL',
#  'AMIT KUMAR',
#  'NEHA SAINI',
#  'NARESH CHAHAL',
#  'PARDEEP',
#  'PUSHKAR MISHRA',
#  'RAJESH KUMAR',
#  'MUKESH',
#  'RITESH',
#  'ARTI DEVI',
#  'AVTAR SINGH',
#  'JITESH KUMAR',
#  'JAGDEEP SINGH CHOPRA',
#  'AJAY',
#  'TEJAS',
#  'HEENA AGGARWAL',
#  'ANAND KUMAR VATSA',
#  'PANKAJ SANGWAN',
#  'PINKI VERMA',
#  'RAHUL DOGRA',
#  'VINAY KUMAR KHURANA',
#  'GOLDY',
#  'LOVEPREET LOVELY',
#  'VIJAY YADAV',
#  'ISHU JUNEJA',
#  'SHIKHAR WADHWA',
#  'GOURAV',
#  'MANJEET',
#  'SUSHANT BECTOR',
#  'PARTEEK',
#  'SAHIL GARG',
#  'MANJEET SINGH',
#  'SARITA ARORA',
#  'ASHU TAUR',
#  'ANIL PAL',
#  'MANISH BISHNOI',
#  'PAWAN KALYAN',
#  'PRABHJOT SINGH',
#  'JITENDER SINGH',
#  'ROHIT NARWAL',
#  'ARJUN SINGH',
#  'AMAN CHAUHAN',
#  'SUNDAR MOHAN SATPATHY',
#  'AJAY',
#  'DHRUV KUMAR',
#  'NARENDER',
#  'RAM BHAJ',
#  'ANKUSH',
#  'RAHUL BHAN',
#  'SAHIL KUMAR',
#  'ASHISH KUMAR',
#  'VINAY',
#  'DEEPAK',
#  'ROSHAN SINGH',
#  'ANJALI SEHGAL',
#  'AARJU',
#  'SHAKTI SIWACH',
#  'PRAVEEN KUMAR',
#  'NITISH',
#  'SAHIL DESHAD',
#  'JYOTI',
#  'NEERAJ',
#  'TARESH KHAMPA',
#  'VIKAS',
#  'SUMIT SIWACH',
#  'VINOD KUMAR',
#  'VINAY ROHILLA',
#  'RAVI',
#  'RAMEHAR',
#  'SAHIL THAKUR',
#  'NAVEEN KUMAR',
#  'AKSHAY',
#  'MONIKA',
#  'DEEPAK KUMAR',
#  'VIVEK BISHT',
#  'MANISH KUMAR',
#  'ANIL KUMAR',
#  'ROHAN DHAIYA',
#  'JAIHIND',
#  'PAWAN KUMAR',
#  'ANIL',
#  'DEEPAK HOODA',
#  'PAWAN',
#  'PRAVESH KUMAR',
#  'VINEET KUMAR',
#  'ANKUR DHAWAN',
#  'ARTI SINGH',
#  'NARESH KUMAR',
#  'DINESH',
#  'AJAY',
#  'DIWANSHI VERMA',
#  'DEVI LAL',
#  'ANJALI BACHCHAS',
#  'AMIT',
#  'SUKHJIT KAUR',
#  'RANJODH SINGH',
#  'NEHA KUMARI',
#  'AMARJEET',
#  'SANDEEP KUMAR',
#  'JEEWAN SINGH RAWAT',
#  'SANJAY SINGH',
#  'PARVEEN KUMAR',
#  'POOJA TIWARI',
#  'ABHISHEK KUMAR',
#  'AMIT KHOKHAR',
#  'SANDEEP KUMAR',
#  'RAHUL SAINI',
#  'AMAN KUMAR',
#  'JATIN GUPTA',
#  'GAURAV MAMGAIN',
#  'SACHIN KALIA',
#  'DEEPAK',
#  'PARVEEN KUMAR',
#  'SUMIT GILL',
#  'DIPENDER SINGH',
#  'VANI KHANDELWAL',
#  'VIJAY SAINI',
#  'ANIL',
#  'SATISH JAIN',
#  'MONU',
#  'AKHILESH SHARMA',
#  'SARVJYOT KAUR',
#  'AMAN',
#  'RITU RAWAT',
#  'AMIT',
#  'DEV VART AGARWAL',
#  'HARNEK SINGH',
#  'VIVEK',
#  'MANDEEP KUMAR',
#  'AJAY KUMAR',
#  'NIDHITA RAJ',
#  'PARDEEP KUMAR',
#  'VINEY KUMAR',
#  'SACHIN',
#  'SURENDER SINGH',
#  'VIJAY BOORA',
#  'DIVYA',
#  'ABHIMANYU',
#  'PRITAM LAL',
#  'MANJEET JAKHAR',
#  'VIJAY ANAND',
#  'ARSHDEEP SINGH',
#  'DHARMENDER',
#  'SOURAV GILL',
#  'RAMANDEEP',
#  'RAVINDER SINGH',
#  'NAINDEEP',
#  'KIRTI NAKRA',
#  'NAVEEN',
#  'RAVINDER KUMAR',
#  'RISHIKA',
#  'BHARTENDU',
#  'PARMINDER KUMAR',
#  'BALRAM MEENA',
#  'ANKUSH KUMAR',
#  'TAJINDER SINGH',
#  'SUNIL KUMAR SANGWAN',
#  'AJIT SINGH CHAUHAN',
#  'DINESH KUMAR',
#  'JAGMINDER KUMAR',
#  'SAHIL',
#  'SWATI',
#  'DAKSH NAYYER',
#  'ANNU SANKHLA',
#  'AJAY SINGH',
#  'AAKANKSHA DOGRA',
#  'CHANDER MOHAN',
#  'MAANVI GAHLOT',
#  'VARUN SAPRA',
#  'PAYAL GARG',
#  'VARISHA',
#  'RITUL RAJ',
#  'RAVI KUMAR',
#  'PREETI KUMARI',
#  'SUNNY',
#  'MANISHA',
#  'PRIYANKA SHARMA',
#  'DEEPMALA DANGI',
#  'ROHTASH VAKIL',
#  'GEETA',
#  'PANKAJ KUMAR YADAV',
#  'KAVITA RANI',
#  'ANIL KUMAR',
#  'AKANKSHA TOMAR',
#  'RAVINA',
#  'NANSI BHONSLE',
#  'DEEPAK KUMAR',
#  'SHIWANI',
#  'HIMANI BASATIYA',
#  'DEEKSHA',
#  'SOURABH KOTHIYAL',
#  'KOMAL',
#  'SWATI',
#  'ANSHIKA',
#  'RACHNA BHATIA',
#  'SHIWANI RANI',
#  'HIMANSHU KUNDU',
#  'KOMAL',
#  'CHANDER HARNUAL',
#  'MEENAKSHI',
#  'MANSI',
#  'PRIYANKA DEVI',
#  'HIMANSHU',
#  'SHIVANI',
#  'NITENDRA PRATAP SINGH',
#  'RAN',
#  'NEHA',
#  'VISHAL CHAUDHARY',
#  'SAKSHI',
#  'MONIL KUMAR',
#  'AANCHAL ROHILLA',
#  'NANCY SHARMA',
#  'HARSHUL',
#  'KESHAV VERMA',
#  'NEHA NAGAL',
#  'KAJAL',
#  'DEEPAK SINGH NEGI',
#  'POOJA RANI',
#  'RAVI KUMAR',
#  'SUNIL KUMAR',
#  'ANURAG BAJPAI',
#  'RUPINDER SINGH',
#  'VAISHALI PRASAD',
#  'SUKIRTI',
#  'DARSHAN SINGH',
#  'ABHILAKSH SAINI',
#  'SANJAY BOHRA',
#  'MONIKA',
#  'DEEPAK SINGH',
#  'TANVEET KAUR',
#  'ABHISHEK GAUTAM',
#  'ISRAR AHAMAD',
#  'DEVENDRA KUMAR SHUKLA',
#  'MONIKA',
#  'ATUL KUMAR SINGH',
#  'KAMAL',
#  'ROHIT KUMAR',
#  'GAURAV KAUSHAL',
#  'SWATI RAJBHAR',
#  'NITISH KUMAR',
#  'ASHWANI BIST',
#  'RAJAT',
#  'SUSHMITA CHAUHAN',
#  'AARJU BHARDWAJ',
#  'KAVITA',
#  'ISHA',
#  'ROHIT VARMA',
#  'SHIVAM PRAKASH SHUKLA',
#  'KAMLESHWAR PRASAD BIJALWA',
#  'ANIL KUMAR',
#  'AMIT KUMAR',
#  'ABHISHEK SINGH',
#  'VIKAS KUMAR',
#  'SURAJ GUPTA',
#  'SWETA',
#  'ROBIN SINGH',
#  'HARISH SINGH DUNGRIYAL',
#  'RAHUL BAHUGUNA',
#  'SACHIN KUMAR',
#  'VINAY KUMAR',
#  'RAJAT KOTHIYAL',
#  'SAAJAN CHAUDHARY',
#  'AVIRAL CHAND RAMOLA',
#  'NIKHIL KUMAR',
#  'RAJBAR SINGH PANWAR',
#  'ANUJA DIMRI',
#  'NIKHIL MAITHANI',
#  'NEHA CHAUHAN',
#  'AMIT NEGI',
#  'PRAVEEN KUMAR SINGH',
#  'ABHISHEK SINGH',
#  'SHUBHAM CHOUDHARY',
#  'VISHAL DESAI',
#  'PRAMOD SINGH PUNDIR',
#  'MANOJ KUMAR',
#  'MAHAVEER PRASAD GAUR',
#  'SURESH CHAUHAN',
#  'AMBIKA TOMAR',
#  'SHILPA CHAUHAN',
#  'KISHOR SINGH BISHT',
#  'GANGA SINGH',
#  'PARTIBHA',
#  'PRADEEP KUMAR BISHT',
#  'ANJALI RAWAT',
#  'SHAGUN UNIYAL',
#  'DIKSHA KUMARI',
#  'NIKLESH SINGH',
#  'RAJAN SINGH THAKUR',
#  'ROHAN CHAUHAN',
#  'PRADUM KUMAR',
#  'RAHUL RAJ',
#  'SANGEETA RAWAT',
#  'ARUN MATHPAL',
#  'JYOTI',
#  'VIKAS SINGH TOMAR',
#  'ALOK PRABHAKAR',
#  'ABHISHEK',
#  'KAVITA BISHT',
#  'GARIMA HINGORANI',
#  'PRIYANSHU THAPLIYAL',
#  'MAHAVEER SINGH',
#  'RAJESH KOHLI',
#  'NEERAJ BISHT',
#  'ANUBHAV GUNSOLA',
#  'PARVIND CHAUHAN',
#  'HIMANSHU TIWARI',
#  'SANDEEP KUMAR GURUNG',
#  'PRIYANKA BADONI',
#  'DEEP SAGAR TEWARI',
#  'DEEPAK SINGH BOUNAL',
#  'DEEPAK KUMAR DABRAL',
#  'SUNDER LAL',
#  'KULDEEP JUNG THAPA',
#  'VIVEK RAWAT',
#  'VAISHALI GUPTA',
#  'AMIT NEGI',
#  'ASHOK KUMAR MEENA',
#  'MUKESH',
#  'SHUKLA ZILAJEET BABULAL',
#  'GOVIND RAM MISHRA',
#  'ANKIT DHULIYA',
#  'VED PRAKASH JOSHI',
#  'ABHAY BIST',
#  'ABHISHEK CHAUHAN',
#  'NITISH RAWAT',
#  'RAJESH SINGH',
#  'ANKITA BHANDARI',
#  'KAMAL KISHORE',
#  'PRIYA SHARMA',
#  'HARSHIT SHARMA',
#  'ATUL KUMAR MAURYA',
#  'ANKIT KUMAR',
#  'SUDHIR CHAUHAN',
#  'LALIT KUMAR',
#  'ANIL PRASAD',
#  'SANJEEV KAUL',
#  'NAVNEET KUMAR SINGH',
#  'ASHU SHARMA',
#  'ANMOL SEMWAL',
#  'KM SHIVANI DEVI',
#  'SURAJ RANA',
#  'GAJENDRA SINGH',
#  'SAURAV ADHIKARI',
#  'RAGHUBEER SINGH BISHT',
#  ...]

# %%
In [40]:
# !pip install pdfminer
# !pip install PyPDF2
import io
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfpage import PDFPage
import PyPDF2
import os

def get_pdf_text(inputFileName):
    with open(inputFileName, 'rb') as fh:
        string = ''
        for page in PDFPage.get_pages(fh, caching=True, check_extractable=True):
            resource_manager = PDFResourceManager()
            fake_file_handle = io.StringIO()
            converter = TextConverter(resource_manager, fake_file_handle)
            page_interpreter = PDFPageInterpreter(resource_manager, converter)
            page_interpreter.process_page(page)
            s = fake_file_handle.getvalue()
            s = s.replace('\n' , '')
            s = ' '.join(s.split())
            string+=s+"\n"
            converter.close()
            fake_file_handle.close()
    answer = ''
    for i in range(len(string)-1):
        if string[i]=='\n' and string[i+1]=='\n':
            pass
        else:
            answer+=string[i]
    pdf_obj = open(inputFileName, 'rb')
    pdfReader = PyPDF2.PdfFileReader(pdf_obj)
    title = pdfReader.getDocumentInfo().title
    pdf_obj.close()
    return answer, title

def get_pdf_roll_no(data):
    import re
    roll_no = re.findall(r'\b\d{10}\b', data)
    return roll_no

def get_pdf_data(inputFileName):
    text, title = get_pdf_text(inputFileName)
    return get_pdf_roll_no(text)
In [41]:
roll_no_1 = get_pdf_data("../LIST3_ROLL-LDC_25022020.pdf")
roll_no_2 = get_pdf_data("../LIST_3_01042021.pdf")
In [42]:
list(set(roll_no_1).intersection(set(roll_no_2)))
Out[42]:
['3206625148',
 '4410036229',
 '2201018043',
 '2201044568',
 '2201187468',
 '2201061462',
 '2201086499',
 '2405077361',
 '2407002881',
 '2201003948',
 '2405049943',
 '8007018878',
 '2405082325',
 '4410086102',
 '2405004922',
 '2405030873',
 '1402205105',
 '2201031784',
 '2201109638',
 '2201063670',
 '2201022593',
 '2405037045',
 '2201125354',
 '3003700151',
 '2402011026',
 '3205400014',
 '2201061050',
 '2201186225',
 '2405086814',
 '2201163191',
 '4410020583',
 '2405045488',
 '2201051799',
 '2201162389',
 '4410004947',
 '2404005343',
 '8202004516',
 '8201001570',
 '4410022020',
 '2408004145',
 '8601013491',
 '2405106846',
 '3206004050',
 '4410040703',
 '2405060881',
 '3010323729',
 '2002014355',
 '2201172663',
 '2201070787',
 '2405095019',
 '9001000323',
 '2201185852',
 '2201132130',
 '2201191054',
 '2405014731',
 '4410077028',
 '3010013642',
 '8201017260',
 '2201023876',
 '2402004851',
 '8204003960',
 '3206301495',
 '4410073383',
 '2402015945',
 '8601036602',
 '4605000502',
 '3206642128',
 '3009005247',
 '3206700242',
 '4410011673',
 '2003006881',
 '2201020301',
 '2201106236',
 '4410025401',
 '2201003933',
 '2201086560',
 '1402205647',
 '2201083543',
 '8204004932',
 '2405020247',
 '3201301781',
 '2404005104',
 '4410045701',
 '2201110312',
 '2401002313',
 '2405011200',
 '3206023012',
 '4205054357',
 '3003100411',
 '2404003370',
 '2405063161',
 '4410000582',
 '2405018947',
 '2405074021',
 '2201028872',
 '2404007964',
 '2201115987',
 '2201127545',
 '2404004899',
 '2201042872',
 '2405023502',
 '3009319950',
 '2201169997',
 '2404007120',
 '4410082875',
 '2405093063']
In [ ]:

In [ ]:

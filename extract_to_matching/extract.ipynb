# %%
l = ['~~~~~~~~~~~~~~~ Record#',
 'ROLL',
 'NAME',
 'CAT1 CAT2 CAT3',
 'CATSEL POSTSEL RANK',
 'REJPROV']

# %%
# !pip install pdfminer
# !pip install PyPDF2
import io
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfpage import PDFPage
import PyPDF2
import os
import math

def get_pdf_text(inputFileName,a):
    text_list = []
    with open(inputFileName, 'rb') as fh:
        for page in PDFPage.get_pages(fh, caching=True, check_extractable=True):
            resource_manager = PDFResourceManager()
            fake_file_handle = io.StringIO()
            converter = TextConverter(resource_manager, fake_file_handle)
            page_interpreter = PDFPageInterpreter(resource_manager, converter)
            page_interpreter.process_page(page)
            s = fake_file_handle.getvalue()
            s = s.split("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            converter.close()
            fake_file_handle.close()
            try:
                text_list.append(get_name(s[a]))
            except:
                continue
    return text_list

def get_pdf_roll_no(data):
    import re
    roll_no = re.findall(r'\b\d{10}\b', data)
    return roll_no

def get_name(data):
    name = []
    roll_number = []
    temp = []
    text = data.split(' ')
    n = len(text)
    c = 0
    while c<n:
        if text[c] != "":
            try:
                p = text[c].replace('.',"")
                p = p.strip()
                p = int(p)
                if math.floor(math.log10(p)+1) == 10:
                    roll_number.append(p)
            except:
                try:
                    p = text[c+1].replace('.',"")
                    p = int(p)
                    name.append(text[c])
                except:
                    try:
                        p = text[c+2].replace('.',"")
                        p = int(p)
                        name.append(text[c]+" "+text[c+1].strip)
                        c += 1
                    except:
                        name.append(text[c] + " " + text[c+1] + " "+ text[c+2])
                        c += 2
        c+=1
    for x in name:
        if x.find('0') != -1:
            name.remove(x)
        
    return name
    
def get_pdf_data(inputFileName,a):
    text = get_pdf_text(inputFileName,a)
    temp = []
    for t in text:
        for x in t:
            x = x.strip()
            if x not in l and len(x) > 4 and x.find("\\") == -1:
                temp.append(x)
    return temp

# %%
name1 = get_pdf_data("LIST3_ROLL-LDC_25022020.pdf",2)
name2 = get_pdf_data("LIST_3_01042021.pdf",1)
name3 = get_pdf_data("../../LIST_1_01042021.pdf",1)
name4 = get_pdf_data("../../LIST_2_01042021.pdf",1)

# %%
len(list(set(name1).intersection(set(name2))))
# Out:
# 3685

# %%
len(list(set(name1).intersection(set(name4))))
# Out:
# 131

# %%
len(list(set(name2).intersection(set(name3))))
# Out:
# 67

# %%
len(list(set(name1).intersection(set(name3))))
# Out:
# 124

# %%
len(list(set(name2).intersection(set(name4))))
# Out:
# 59

# %%
len(name1)
# Out:
# 30510

# %%
len(name2)
# Out:
# 10551

# %%
len(name3)
# Out:
# 294

# %%
len(name4)
# Out:
# 272

# %%
list(set(name1).intersection(set(name2)))
# Out:
# ['PAWAN KANAUJIA',
#  'TRIBENDU BISWAS',
#  'MUKESH DHIMAN',
#  'MRIDUL SINGH',
#  'RAJEEV SHARMA',
#  'PRIYANKA GUPTA',
#  'MANISH BADARDA',
#  'ABHINAV MISHRA',
#  'GOPAL VERMA',
#  'KAMAL KISHORE MISARA',
#  'KRISHNANAND',
#  'DEBJIT MONDAL',
#  'RAHUL MISHRA',
#  'PRAKASH VERMA',
#  'RUPAM MAITY',
#  'SANDEEP SINGH',
#  'ABHILASH GP',
#  'PANKAJ MAVI',
#  'JAYA CHAUHAN',
#  'SOUMYA GOEL',
#  'RAHUL KUMAR SANKHALA',
#  'PIYUSH PUSKAR',
#  'BADAVATH VIJAY',
#  'BIJENDER',
#  'DEEPAK SHARMA',
#  'DIPANJAN BISWAS',
#  'ANKIT KAUSHIK',
#  'RANVEER SINGH',
#  'RAVI PAL',
#  'DHIRAJ KUMAR YADAV',
#  'VINAY KRISHNA GOPISETTI',
#  'NEERAJ JAISWAL',
#  'RISHI KUMAR',
#  'GIRIWAR YADAV',
#  'MAHIMA SHARMA',
#  'NITESH',
#  'DHEERAJ SUREDHA',
#  'SOMNATH CHANDRA',
#  'AMIT KUMAR HINONIYA',
#  'SUNNY KUMAR',
#  'ABHISHEK BISHT',
#  'ARJUN RAM',
#  'ACHAL SINGH',
#  'MOHIT SONI',
#  'LALITA',
#  'SHWETA RANI',
#  'VINITA',
#  'SHIVANI',
#  'SHAMSHER SINGH',
#  'AKHILESH KUMAR SHARMA',
# ...

# %%
list(set(name1).intersection(set(name4)))
# Out:
# ['GOVIND SINGH',
#  'YOGENDRA SINGH',
#  'BHARAT BHUSHAN JHA',
#  'LOVE KUMAR MEENA',
#  'PRADEEP KUMAR',
#  'NITIN',
#  'VISHAL KUMAR SINGH',
#  'SNEHA MISRA',
#  'DEEPAK KUMAR',
#  'BHASHAKAR KUMAR JHA',
#  'BABULAL MEENA',
#  'RAHUL DEV THAKUR',
#  'ABHIJIT TAPADAR',
#  'AJAY KUMAR SHARMA',
#  'AMRINDER SINGH',
#  'NITISH KUMAR',
#  'CHANDAN SINGH',
#  'BARNALI SAMANTA',
#  'NIKHIL GUPTA',
#  'AMIT SHUKLA',
#  'RAMNARESH MEENA',
#  'PAWAN KUMAR KHAKRE',
#  'SHIVAM SRIVASTAVA',
#  'DEEPSHIKHA',
#  'MANIT KUMAR',
#  'SWATI',
#  'KUNAL KUMAR',
#  'DEVESH',
#  'VIKASH MEENA',
#  'MONIKA',
#  'HARISH SHARMA',
#  'ANAND TIWARI',
#  'IMRAN KHAN',
#  'ARVIND KUMAR GANGWAR',
#  'RAVINDRA KUMAR MEENA',
#  'VINOD KUMAR G',
#  'PAWAN KUMAR',
#  'BRIJESH KUMAR SHARMA',
#  'SANDEEP GUPTA',
#  'VINOD RAY',
#  'ANIL KUMAR',
#  'NISHANT',
#  'ABHISHEK KUMAR',
#  'ARVIND KUMAR',
#  'ABINASH SWAIN',
#  'SATYENDRA KUMAR',
#  'LALIT KUMAR',
#  'SUDAKSHINA GHOSH',
#  'VINOD KUMAR BAIRWA',
#  'MADHUR',
# ...

# %%
list(set(name2).intersection(set(name3)))
# Out:
# ['GAGANDEEP SINGH',
#  'AJIT KUMAR',
#  'MANISH KUMAR',
#  'RAJENDER KUMAR',
#  'RAHUL YADAV',
#  'KARAN KUMAR',
#  'VIVEK SHARMA',
#  'SACHIN',
#  'ROHIT KUMAR',
#  'VINAY KUMAR',
#  'SOMVEER',
#  'PRAKASH KUMAR',
#  'DEEPAK KUMAR',
#  'HIMANSHU',
#  'ANIL KUMAR',
#  'PREET SINGH',
#  'NITISH AGGARWAL',
#  'YOGESH KUMAR MEENA',
#  'AKSHYA KUMAR',
#  'NEERAJ',
#  'SHIVAM SHARMA',
#  'SHIVAM GUPTA',
#  'VAISHALI',
#  'ANKIT',
#  'ABHISHEK',
#  'RAVI VERMA',
#  'AJEET KUMAR',
#  'RAVINDER KUMAR',
#  'ADITYA',
#  'POONAM YADAV',
#  'RAHUL KUMAR SINGH',
#  'AVNEESH KUMAR',
#  'SHUBHAM KUMAR',
#  'POOJA',
#  'PANKAJ SAINI',
#  'RAHUL SHARMA',
#  'RAJAN KUMAR',
#  'PURUSHOTTAM KUMAR',
#  'AMIT KUMAR SINGH',
#  'PRADEEP',
#  'SACHIN KUMAR',
#  'HARIOM MEENA',
#  'SAURABH KUMAR',
#  'RAVINDER',
#  'GAURAV YADAV',
#  'JATIN',
#  'NAVDEEP',
#  'VIKAS KUMAR MEENA',
#  'ANKIT KUMAR',
#  'ANAND KUMAR',
#  'PRABHAT RANJAN',
#  'RAHUL KUMAR',
#  'NAVEEN KUMAR',
#  'DEEPAK CHAUDHARY',
#  'PREETI',
# ...

# %%
list(set(name1).intersection(set(name3)))
# Out:
# ['PAWAN KUMAR YADAV',
#  'MANOJ KUMAR BAIRWA',
#  'PREETAM SINGH MEENA',
#  'MANISH KUMAR',
#  'ROHIT KUMAR',
#  'RISHABH KANNOJIYA',
#  'BHUPENDRA MEENA',
#  'DEEPAK KUMAR',
#  'HIMANSHU',
#  'AVNEESH KUMAR',
#  'ASHUTOSH VERMA',
#  'MOHIT GUPTA',
#  'RAHUL SHARMA',
#  'PURUSHOTTAM KUMAR',
#  'SACHIN RATHEE',
#  'HEMRAJ',
#  'VIKAS KUMAR MEENA',
#  'ARKESH KUMAR PANDEY',
#  'PRABHAT RANJAN',
#  'AKULA NIHAL',
#  'GAURAV KUMAR',
#  'AKASH YADAV',
#  'MAYANK',
#  'DEVENDRA MEENA',
#  'SHUBHAM GAUR',
#  'KULDEEP',
#  'GAGANDEEP SINGH',
#  'RAJNI KUMARI',
#  'AJIT KUMAR',
#  'GAURAV MALIK',
#  'ANSHUL SHARMA',
#  'ABHISHEK PRATAP',
#  'RAHUL YADAV',
#  'SACHIN',
#  'RINKU MEENA',
#  'UJJAWAL GUPTA',
#  'ANIL KUMAR',
#  'SHIVAM GUPTA',
#  'ANKIT',
#  'NISHA HARISH IYER',
#  'ABHISHEK',
#  'MOHD ARIF',
#  'RAVI VERMA',
#  'RAVINDER KUMAR',
#  'AJEET KUMAR',
#  'PRAVIN SINGH',
#  'SHAKTI PARASHAR',
#  'SHUBHAM KUMAR',
#  'POOJA',
#  'PANKAJ SAINI',
#  'UJJAWAL KUMAR',
#  'HARIOM MEENA',
# ...

# %%
list(set(name2).intersection(set(name4)))
# Out:
# ['SWATI',
#  'KUNAL KUMAR',
#  'VIKASH MEENA',
#  'MONIKA',
#  'HARISH SHARMA',
#  'RANDEEP SINGH',
#  'YOGENDRA SINGH',
#  'VIVEK KUMAR',
#  'ANAND TIWARI',
#  'PRADEEP KUMAR',
#  'ABHAY KUMAR PANDEY',
#  'SAGAR SHARMA',
#  'NITESH KUMAR YADAV',
#  'RANJEET KUMAR',
#  'RAVINDRA KUMAR MEENA',
#  'SUNIL KUMAR',
#  'NITIN',
#  'VISHAL KUMAR SINGH',
#  'PAWAN KUMAR',
#  'SANDEEP GUPTA',
#  'DEEPAK KUMAR',
#  'RAJEEV RANJAN',
#  'SHUBHAM KHANDELWAL',
#  'HARSH GUPTA',
#  'ANIL KUMAR',
#  'NISHANT',
#  'ABHISHEK KUMAR',
#  'SAGAR KUMAR',
#  'AJAY SINGH',
#  'ARVIND KUMAR',
#  'MANISH MEENA',
#  'KUMAR GAURAV',
#  'NARESH KUMAR',
#  'LALIT KUMAR',
#  'PRAKASH MEENA',
#  'RAMAN',
#  'NITISH KUMAR',
#  'AMIT KUMAR SINGH',
#  'ARPAN SARKAR',
#  'CHANDAN SINGH',
#  'ASHWANI KUMAR',
#  'SANDEEP VERMA',
#  'NIKHIL GUPTA',
#  'SANJEET',
#  'SUNIL KUMAR MEENA',
#  'JITENDER KUMAR',
#  'KUNDAN KUMAR',
#  'ANKIT KUMAR',
#  'AMIT SHUKLA',
#  'RAMNARESH MEENA',
#  'ARNAB CHOWDHURY',
# ...

# %%
list(set(name3).intersection(set(name4)))
# Out:
# ['ANKIT KUMAR',
#  'DEEPAK KUMAR',
#  'ANIL KUMAR',
#  'AMIT KUMAR SINGH',
#  'NITESH KUMAR']

# %%
In [40]:
# !pip install pdfminer
# !pip install PyPDF2
import io
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfpage import PDFPage
import PyPDF2
import os

def get_pdf_text(inputFileName):
    with open(inputFileName, 'rb') as fh:
        string = ''
        for page in PDFPage.get_pages(fh, caching=True, check_extractable=True):
            resource_manager = PDFResourceManager()
            fake_file_handle = io.StringIO()
            converter = TextConverter(resource_manager, fake_file_handle)
            page_interpreter = PDFPageInterpreter(resource_manager, converter)
            page_interpreter.process_page(page)
            s = fake_file_handle.getvalue()
            s = s.replace('\n' , '')
            s = ' '.join(s.split())
            string+=s+"\n"
            converter.close()
            fake_file_handle.close()
    answer = ''
    for i in range(len(string)-1):
        if string[i]=='\n' and string[i+1]=='\n':
            pass
        else:
            answer+=string[i]
    pdf_obj = open(inputFileName, 'rb')
    pdfReader = PyPDF2.PdfFileReader(pdf_obj)
    title = pdfReader.getDocumentInfo().title
    pdf_obj.close()
    return answer, title

def get_pdf_roll_no(data):
    import re
    roll_no = re.findall(r'\b\d{10}\b', data)
    return roll_no

def get_pdf_data(inputFileName):
    text, title = get_pdf_text(inputFileName)
    return get_pdf_roll_no(text)
In [41]:
roll_no_1 = get_pdf_data("../LIST3_ROLL-LDC_25022020.pdf")
roll_no_2 = get_pdf_data("../LIST_3_01042021.pdf")
In [42]:
list(set(roll_no_1).intersection(set(roll_no_2)))
Out[42]:
['3206625148',
 '4410036229',
 '2201018043',
 '2201044568',
 '2201187468',
 '2201061462',
 '2201086499',
 '2405077361',
 '2407002881',
 '2201003948',
 '2405049943',
 '8007018878',
 '2405082325',
 '4410086102',
 '2405004922',
 '2405030873',
 '1402205105',
 '2201031784',
 '2201109638',
 '2201063670',
 '2201022593',
 '2405037045',
 '2201125354',
 '3003700151',
 '2402011026',
 '3205400014',
 '2201061050',
 '2201186225',
 '2405086814',
 '2201163191',
 '4410020583',
 '2405045488',
 '2201051799',
 '2201162389',
 '4410004947',
 '2404005343',
 '8202004516',
 '8201001570',
 '4410022020',
 '2408004145',
 '8601013491',
 '2405106846',
 '3206004050',
 '4410040703',
 '2405060881',
 '3010323729',
 '2002014355',
 '2201172663',
 '2201070787',
 '2405095019',
 '9001000323',
 '2201185852',
 '2201132130',
 '2201191054',
 '2405014731',
 '4410077028',
 '3010013642',
 '8201017260',
 '2201023876',
 '2402004851',
 '8204003960',
 '3206301495',
 '4410073383',
 '2402015945',
 '8601036602',
 '4605000502',
 '3206642128',
 '3009005247',
 '3206700242',
 '4410011673',
 '2003006881',
 '2201020301',
 '2201106236',
 '4410025401',
 '2201003933',
 '2201086560',
 '1402205647',
 '2201083543',
 '8204004932',
 '2405020247',
 '3201301781',
 '2404005104',
 '4410045701',
 '2201110312',
 '2401002313',
 '2405011200',
 '3206023012',
 '4205054357',
 '3003100411',
 '2404003370',
 '2405063161',
 '4410000582',
 '2405018947',
 '2405074021',
 '2201028872',
 '2404007964',
 '2201115987',
 '2201127545',
 '2404004899',
 '2201042872',
 '2405023502',
 '3009319950',
 '2201169997',
 '2404007120',
 '4410082875',
 '2405093063']
In [ ]:

In [ ]:
